# %% [markdown]
# ## **Threads** 🪢

# %% [markdown]
# ### **Autoras** 👩‍💻
#
# Desenvolvedores que contribuíram para a estruturação e desenvolvimento deste projeto:
#
# - **Iza Lopes Ribeiro** - [Izalp](https://github.com/Izalp)
# - **Wiliane Carolina Silva** - [wilicarol](https://github.com/wilicarol)

# %% [markdown]
# ### **Apresentação da ideia** 💡
#
#  Uma simulação em Python que imita vários eventos esportivos olímpicos ocorrendo simultaneamente, usando threads. Este projeto demonstra como lidar com concorrência e paralelismo em Python enquanto simula os diversos eventos que acontecem durante os Jogos Olímpicos.

# %% [markdown]
# #### **Esportes que serão simulados** 🕹️
#
# | **Categoria**            | **Esportes**                                                                                   |
# |--------------------------|-----------------------------------------------------------------------------------------------|
# | Atletismo                | Atletismo                                                                                      |
# | Esportes de Raquete       | Badminton, Tênis, Tênis de Mesa                                                                |
# | Esportes de Equipe        | Basquete, Basquete 3x3, Futebol, Handebol, Rugby Sevens, Vôlei, Vôlei de Praia                |
# | Lutas                     | Boxe, Judô, Luta, Taekwondo                                                                    |
# | Danças                    | Breaking                                                                                      |
# | Esportes Aquáticos        | Canoagem de Velocidade, Canoagem Slalom, Maratona Aquática, Nado Artístico, Natação, Polo Aquático, Saltos Ornamentais, Surfe |
# | Ciclismo                  | Ciclismo BMX Freestyle, Ciclismo BMX Racing, Ciclismo de Estrada, Ciclismo de Pista, Ciclismo Mountain Bike |
# | Esportes de Montanha      | Escalada                                                                                     |
# | Esgrima                   | Esgrima                                                                                      |
# | Ginástica                 | Ginástica Artística, Ginástica de Trampolim, Ginástica Rítmica                                |
# | Golfe                     | Golfe                                                                                        |
# | Esportes Equestres        | Hipismo                                                                                      |
# | Esportes de Campo         | Hóquei Sobre Grama                                                                            |
# | Levantamento de Peso      | Levantamento de Peso                                                                          |
# | Esportes de Remo          | Remo                                                                                         |
# | Tiro                      | Tiro com Arco, Tiro Esportivo                                                                 |
# | Multiesportes             | Triatlo                                                                                      |
# | Esportes Radicais         | Skate                                                                                       |
# | Vela                      | Vela                                                                                         |

# %% [markdown]
# ### **Passos para executar o projeto localmente** 🔗
#
# #### 1. **Pré-requisitos**
#
# - [Python 3.6 ou superior](https://www.python.org/downloads/)
# - [Git](https://git-scm.com/downloads) ou cmd (Prompt de Comando)
#
# #### 2. **Instalação**
#
# - Clone o repositório:
#
#   ```bash
#   git clone https://github.com/Izalp/OlympicsThreads.git
#   ```
#
# #### 3. **Execução**
#
# - Execute a simulação usando o comando:
#   ```bash
#   python start_olympics/olympics.py
#   ```

# %% [markdown]
# ### **Código** 💻

# %%
import threading
import time
import random
from sports import sports

# Função para simular a execução do esporte, com título e duração específica
def sport(title, duration, daily_total_hours):
    time.sleep(duration)
    daily_total_hours[0] += duration  # Atualiza o total de horas do dia
    print(f'Modalidade {title} concluída após {duration:.3f} horas.')

# Simula o início dos Jogos Olímpicos, distribuindo os esportes ao longo dos dias
def start_olympics():
    print('\nOs Jogos Olímpicos em Paris 2024 foram iniciados!\n')

    day_duration = 12  # Duração máxima de um dia (12 horas)
    day_count = 0  # Contador de dias
    all_sports = sports.copy()  # Lista de todos os esportes
    pending_sports = []  # Lista dos esportes pendentes para o próximo dia

    # Executa enquanto houver esportes a serem realizados
    while all_sports or pending_sports:
        day_count += 1

        print(f'--- Início do dia {day_count} ---\n')

        day_remaining = day_duration  # Tempo restante do dia
        executed_today = []  # Esportes executados no dia
        daily_total_hours = [0]  # Total de horas acumuladas no dia, como lista para ser mutável

        # Executa os esportes pendentes, se houver tempo no dia
        while pending_sports and day_remaining > 0:
            # Remove o primeiro esporte da lista de pendentes
            title, duration = pending_sports.pop(0)

            # Verifica se há tempo suficiente para executar o esporte
            if duration <= day_remaining:
                # Cria uma thread para o esporte
                t = threading.Thread(target=sport, args=(title, duration, daily_total_hours))
                executed_today.append((t, title))

                t.start()  # Inicializa a Thread
                day_remaining -= duration  # Decrementa o tempo do dia a cada esporte executado
            else:
                # Reinsere o esporte na lista de pendentes se não houver tempo suficiente
                pending_sports.insert(0, (title, duration))
                break

        # Executa novos esportes, se houver tempo restante no dia
        while all_sports and day_remaining > 0:
            # Remove o primeiro esporte da lista de todos os esportes
            title = all_sports.pop(0)

            # Duração aleatória (em horas)
            duration = random.uniform((1/60), 5)

            # Verifica se há tempo suficiente para executar o esporte
            if duration <= day_remaining:
                t = threading.Thread(target=sport, args=(title, duration, daily_total_hours))
                executed_today.append((t, title))

                t.start()  # Inicializa as Threads
                day_remaining -= duration  # Decrementa o tempo do dia a cada esporte executado
            else:
                pending_sports.append((title, duration))

        # Espera que todos os esportes do dia sejam concluídos
        for t, title in executed_today:
            t.join()

        # Exibe o resumo dos esportes executados no dia
        executed_sports = ', '.join([title for _, title in executed_today])
        print(
            f'\n--- Fim do dia {day_count} ---\nEsportes executados: {executed_sports}\n')

        # Exibe o total de horas de esportes executados no dia
        print(f'Total de horas de esportes executados no dia {day_count}: {daily_total_hours[0]:.3f} horas\n')

    # Exibe mensagem de finalização dos Jogos Olímpicos
    print(
        f'Os Jogos Olímpicos em Paris 2024 foram finalizados após {day_count} dias!\n')

# Inicia a simulação dos Jogos Olímpicos
start_olympics()
# Out:
# Os Jogos Olímpicos em Paris 2024 foram iniciados!
#
# --- Início do dia 1 ---
#
# Modalidade Boxe concluída após 0.103 horas.
# Modalidade Handebol concluída após 0.875 horas.
# Modalidade Atletismo concluída após 1.000 horas.
# Modalidade Breaking concluída após 1.755 horas.
# Modalidade Badminton concluída após 1.896 horas.
# Modalidade Basquete 3x3 concluída após 2.315 horas.
# Modalidade Basquete concluída após 3.998 horas.
#
# --- Fim do dia 1 ---
# Esportes executados: Atletismo, Badminton, Basquete, Basquete 3x3, Boxe, Breaking, Handebol
#
# Total de horas de esportes executados no dia 1: 11.942 horas
#
# --- Início do dia 2 ---
#
# Modalidade Canoagem de Velocidade concluída após 2.488 horas.
# Modalidade Ciclismo Bmx Freestyle concluída após 2.665 horas.
# Modalidade Canoagem Slalom concluída após 4.903 horas.
#
# --- Fim do dia 2 ---
# Esportes executados: Canoagem de Velocidade, Canoagem Slalom, Ciclismo Bmx Freestyle
#
# Total de horas de esportes executados no dia 2: 10.057 horas
#
# --- Início do dia 3 ---
#
# Modalidade Ciclismo de Pista concluída após 1.325 horas.
# Modalidade Ciclismo Mountain Bike concluída após 1.686 horas.
# Modalidade Ciclismo Bmx Racing concluída após 2.775 horas.
# Modalidade Ciclismo de Estrada concluída após 3.051 horas.
#
# --- Fim do dia 3 ---
# Esportes executados: Ciclismo Bmx Racing, Ciclismo de Estrada, Ciclismo de Pista, Ciclismo Mountain Bike
#
# Total de horas de esportes executados no dia 3: 8.836 horas
#
# --- Início do dia 4 ---
#
# Modalidade Esgrima concluída após 1.678 horas.
# Modalidade Escalada concluída após 3.976 horas.
# Modalidade Futebol concluída após 4.628 horas.
#
# --- Fim do dia 4 ---
# Esportes executados: Escalada, Esgrima, Futebol
#
# Total de horas de esportes executados no dia 4: 10.282 horas
#
# --- Início do dia 5 ---
#
# Modalidade Ginástica de Trampolim concluída após 2.157 horas.
# Modalidade Ginástica Artística concluída após 3.918 horas.
# Modalidade Ginástica Rítmica concluída após 4.657 horas.
#
# --- Fim do dia 5 ---
# Esportes executados: Ginástica Artística, Ginástica de Trampolim, Ginástica Rítmica
#
# Total de horas de esportes executados no dia 5: 10.732 horas
#
# --- Início do dia 6 ---
#
# Modalidade Hóquei sobre Grama concluída após 2.720 horas.
# Modalidade Hipismo concluída após 4.255 horas.
# Modalidade Golfe concluída após 4.649 horas.
#
# --- Fim do dia 6 ---
# Esportes executados: Golfe, Hipismo, Hóquei sobre Grama
#
# Total de horas de esportes executados no dia 6: 11.624 horas
#
# --- Início do dia 7 ---
#
# Modalidade Maratona Aquática concluída após 1.744 horas.
# Modalidade Levantamento de Peso concluída após 1.810 horas.
# Modalidade Luta concluída após 2.870 horas.
# Modalidade Judô concluída após 3.322 horas.
#
# --- Fim do dia 7 ---
# Esportes executados: Judô, Levantamento de Peso, Luta, Maratona Aquática
#
# Total de horas de esportes executados no dia 7: 9.747 horas
#
# --- Início do dia 8 ---
#
# Modalidade Natação concluída após 2.007 horas.
# Modalidade Polo Aquático concluída após 2.172 horas.
# Modalidade Pentatlo Moderno concluída após 2.804 horas.
# Modalidade Nado Artístico concluída após 3.636 horas.
#
# --- Fim do dia 8 ---
# Esportes executados: Nado Artístico, Natação, Pentatlo Moderno, Polo Aquático
#
# Total de horas de esportes executados no dia 8: 10.618 horas
#
# --- Início do dia 9 ---
#
# Modalidade Skate concluída após 0.270 horas.
# Modalidade Saltos Ornamentais concluída após 0.283 horas.
# Modalidade Rugby Sevens concluída após 0.898 horas.
# Modalidade Taekwondo concluída após 2.907 horas.
# Modalidade Surfe concluída após 3.148 horas.
# Modalidade Remo concluída após 4.031 horas.
#
# --- Fim do dia 9 ---
# Esportes executados: Remo, Rugby Sevens, Saltos Ornamentais, Skate, Surfe, Taekwondo
#
# Total de horas de esportes executados no dia 9: 11.537 horas
#
# --- Início do dia 10 ---
#
# Modalidade Tiro com Arco concluída após 2.876 horas.
# Modalidade Tênis concluída após 4.421 horas.
# Modalidade Tênis de Mesa concluída após 4.483 horas.
#
# --- Fim do dia 10 ---
# Esportes executados: Tênis, Tênis de Mesa, Tiro com Arco
#
# Total de horas de esportes executados no dia 10: 11.780 horas
#
# --- Início do dia 11 ---
#
# Modalidade Vela concluída após 0.362 horas.
# Modalidade Vôlei concluída após 2.274 horas.
# Modalidade Tiro Esportivo concluída após 3.885 horas.
# Modalidade Triatlo concluída após 4.716 horas.
#
# --- Fim do dia 11 ---
# Esportes executados: Tiro Esportivo, Triatlo, Vela, Vôlei
#
# Total de horas de esportes executados no dia 11: 11.237 horas
#
# --- Início do dia 12 ---
#
# Modalidade Vôlei de Praia concluída após 4.642 horas.
#
# --- Fim do dia 12 ---
# Esportes executados: Vôlei de Praia
#
# Total de horas de esportes executados no dia 12: 4.642 horas
#
# Os Jogos Olímpicos em Paris 2024 foram finalizados após 12 dias!

# %% [markdown]
# ### **Agradecemos a atenção!** 😊
