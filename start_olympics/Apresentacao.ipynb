# %% [markdown]
# ## **Threads** 🪢

# %% [markdown]
# ### **Autoras** 👩‍💻
#
# Desenvolvedores que contribuíram para a estruturação e desenvolvimento deste projeto:
#
# - **Iza Lopes Ribeiro** - [Izalp](https://github.com/Izalp)
# - **Wiliane Carolina Silva** - [wilicarol](https://github.com/wilicarol)

# %% [markdown]
# ### **Apresentação da ideia** 💡
#
#  Uma simulação em Python que imita vários eventos esportivos olímpicos ocorrendo simultaneamente, usando threads. Este projeto demonstra como lidar com concorrência e paralelismo em Python enquanto simula os diversos eventos que acontecem durante os Jogos Olímpicos.

# %% [markdown]
# #### **Esportes que serão simulados** 🕹️
#
# | **Categoria**            | **Esportes**                                                                                   |
# |--------------------------|-----------------------------------------------------------------------------------------------|
# | Atletismo                | Atletismo                                                                                      |
# | Esportes de Raquete       | Badminton, Tênis, Tênis de Mesa                                                                |
# | Esportes de Equipe        | Basquete, Basquete 3x3, Futebol, Handebol, Rugby Sevens, Vôlei, Vôlei de Praia                |
# | Lutas                     | Boxe, Judô, Luta, Taekwondo                                                                    |
# | Danças                    | Breaking                                                                                      |
# | Esportes Aquáticos        | Canoagem de Velocidade, Canoagem Slalom, Maratona Aquática, Nado Artístico, Natação, Polo Aquático, Saltos Ornamentais, Surfe |
# | Ciclismo                  | Ciclismo BMX Freestyle, Ciclismo BMX Racing, Ciclismo de Estrada, Ciclismo de Pista, Ciclismo Mountain Bike |
# | Esportes de Montanha      | Escalada                                                                                     |
# | Esgrima                   | Esgrima                                                                                      |
# | Ginástica                 | Ginástica Artística, Ginástica de Trampolim, Ginástica Rítmica                                |
# | Golfe                     | Golfe                                                                                        |
# | Esportes Equestres        | Hipismo                                                                                      |
# | Esportes de Campo         | Hóquei Sobre Grama                                                                            |
# | Levantamento de Peso      | Levantamento de Peso                                                                          |
# | Esportes de Remo          | Remo                                                                                         |
# | Tiro                      | Tiro com Arco, Tiro Esportivo                                                                 |
# | Multiesportes             | Triatlo                                                                                      |
# | Esportes Radicais         | Skate                                                                                       |
# | Vela                      | Vela                                                                                         |

# %% [markdown]
# ### **Passos para executar o projeto localmente** 🔗
#
# #### 1. **Pré-requisitos**
#
# - [Python 3.6 ou superior](https://www.python.org/downloads/)
# - [Git](https://git-scm.com/downloads) ou cmd (Prompt de Comando)
#
# #### 2. **Instalação**
#
# - Clone o repositório:
#
#   ```bash
#   git clone https://github.com/Izalp/OlympicsThreads.git
#   ```
#
# #### 3. **Execução**
#
# - Execute a simulação usando o comando:
#   ```bash
#   python start_olympics/olympics.py
#   ```

# %% [markdown]
# ### **Código** 💻

# %%
import threading
import time
import random
from sports import sports

# Função para simular a execução do esporte, com título e duração específica
def sport(title, duration, daily_total_hours):
    time.sleep(duration) # (uniform[, dias_limite]) 
    daily_total_hours[0] += duration  # Atualiza o total de horas do dia
    print(f'Modalidade {title} concluída após {duration:.3f} horas.')

# Simula o início dos Jogos Olímpicos, distribuindo os esportes ao longo dos dias
def start_olympics():
    print('\nOs Jogos Olímpicos em Paris 2024 foram iniciados!\n')

    day_duration = 14 # Duração máxima de um dia (12 horas)
    day_count = 0  # Contador de dias
    all_sports = sports.copy()  # Lista de todos os esportes
    pending_sports = []  # Lista dos esportes pendentes para o próximo dia

    # Executa enquanto houver esportes a serem realizados
    while all_sports or pending_sports:
        day_count += 1

        print(f'--- Início do dia {day_count} ---\n')

        day_remaining = day_duration  # Tempo restante do dia
        executed_today = []  # Esportes executados no dia
        daily_total_hours = [0]  # Total de horas acumuladas no dia, como lista para ser mutável

        # Executa os esportes pendentes, se houver tempo no dia
        while pending_sports and day_remaining > 0:
            # Remove o primeiro esporte da lista de pendentes
            title, duration = pending_sports.pop(0)

            # Verifica se há tempo suficiente para executar o esporte
            if duration <= day_remaining:
                # Cria uma thread para o esporte
                t = threading.Thread(target=sport, args=(title, duration, daily_total_hours))
                executed_today.append((t, title))

                t.start()  # Inicializa a Thread
                day_remaining -= duration  # Decrementa o tempo do dia a cada esporte executado
            else:
                # Reinsere o esporte na lista de pendentes se não houver tempo suficiente
                pending_sports.insert(0, (title, duration))
                break

        # Executa novos esportes, se houver tempo restante no dia
        while all_sports and day_remaining > 0:
            # Remove o primeiro esporte da lista de todos os esportes
            title = all_sports.pop(0)

            # Duração aleatória (em horas)
            duration = random.uniform((1/60), 5)

            # Verifica se há tempo suficiente para executar o esporte
            if duration <= day_remaining:
                t = threading.Thread(target=sport, args=(title, duration, daily_total_hours))
                executed_today.append((t, title))

                t.start()  # Inicializa as Threads
                day_remaining -= duration  # Decrementa o tempo do dia a cada esporte executado
            else:
                pending_sports.append((title, duration))

        # Espera que todos os esportes do dia sejam concluídos
        for t, title in executed_today:
            t.join()

        # Exibe o resumo dos esportes executados no dia
        executed_sports = ', '.join([title for _, title in executed_today])
        print(
            f'\n--- Fim do dia {day_count} ---\nEsportes executados: {executed_sports}\n')

        # Exibe o total de horas de esportes executados no dia
        print(f'Total de horas de esportes executados no dia {day_count}: {daily_total_hours[0]:.3f} horas')

    # Exibe mensagem de finalização dos Jogos Olímpicos
    print(
        f'Os Jogos Olímpicos em Paris 2024 foram finalizados após {day_count} dias!\n')

# Inicia a simulação dos Jogos Olímpicos
start_olympics()
# Out:
# Os Jogos Olímpicos em Paris 2024 foram iniciados!
#
# --- Início do dia 1 ---
#
# Modalidade Escalada concluída após 0.511 horas.
# Modalidade Ginástica de Trampolim concluída após 0.923 horas.
# Modalidade Basquete concluída após 3.894 horas.
# Modalidade Badminton concluída após 4.150 horas.
# Modalidade Atletismo concluída após 4.483 horas.
#
# --- Fim do dia 1 ---
# Esportes executados: Atletismo, Badminton, Basquete, Escalada, Ginástica de Trampolim
#
# Total de horas de esportes executados no dia 1: 13.961 horas
# --- Início do dia 2 ---
#
# Modalidade Breaking concluída após 1.718 horas.
# Modalidade Boxe concluída após 2.037 horas.
# Modalidade Canoagem de Velocidade concluída após 3.292 horas.
# Modalidade Basquete 3x3 concluída após 4.700 horas.
#
# --- Fim do dia 2 ---
# Esportes executados: Basquete 3x3, Boxe, Breaking, Canoagem de Velocidade
#
# Total de horas de esportes executados no dia 2: 11.748 horas
# --- Início do dia 3 ---
#
# Modalidade Ciclismo de Estrada concluída após 2.570 horas.
# Modalidade Canoagem Slalom concluída após 2.774 horas.
# Modalidade Ciclismo Bmx Racing concluída após 3.622 horas.
# Modalidade Ciclismo Bmx Freestyle concluída após 4.026 horas.
#
# --- Fim do dia 3 ---
# Esportes executados: Canoagem Slalom, Ciclismo Bmx Freestyle, Ciclismo Bmx Racing, Ciclismo de Estrada
#
# Total de horas de esportes executados no dia 3: 12.991 horas
# --- Início do dia 4 ---
#
# Modalidade Ginástica Artística concluída após 1.472 horas.
# Modalidade Ciclismo de Pista concluída após 1.506 horas.
# Modalidade Futebol concluída após 1.638 horas.
# Modalidade Esgrima concluída após 3.108 horas.
# Modalidade Ciclismo Mountain Bike concluída após 4.868 horas.
#
# --- Fim do dia 4 ---
# Esportes executados: Ciclismo de Pista, Ciclismo Mountain Bike, Esgrima, Futebol, Ginástica Artística
#
# Total de horas de esportes executados no dia 4: 12.592 horas
# --- Início do dia 5 ---
#
# Modalidade Hóquei sobre Grama concluída após 0.283 horas.
# Modalidade Ginástica Rítmica concluída após 1.773 horas.
# Modalidade Golfe concluída após 3.498 horas.
# Modalidade Handebol concluída após 3.515 horas.
# Modalidade Hipismo concluída após 4.113 horas.
#
# --- Fim do dia 5 ---
# Esportes executados: Ginástica Rítmica, Golfe, Handebol, Hipismo, Hóquei sobre Grama
#
# Total de horas de esportes executados no dia 5: 13.181 horas
# --- Início do dia 6 ---
#
# Modalidade Levantamento de Peso concluída após 0.198 horas.
# Modalidade Nado Artístico concluída após 1.596 horas.
# Modalidade Luta concluída após 2.530 horas.
# Modalidade Maratona Aquática concluída após 3.185 horas.
# Modalidade Judô concluída após 4.860 horas.
#
# --- Fim do dia 6 ---
# Esportes executados: Judô, Levantamento de Peso, Luta, Maratona Aquática, Nado Artístico
#
# Total de horas de esportes executados no dia 6: 12.369 horas
# --- Início do dia 7 ---
#
# Modalidade Rugby Sevens concluída após 0.220 horas.
# Modalidade Pentatlo Moderno concluída após 0.513 horas.
# Modalidade Remo concluída após 0.883 horas.
# Modalidade Saltos Ornamentais concluída após 3.636 horas.
# Modalidade Polo Aquático concluída após 4.082 horas.
# Modalidade Natação concluída após 4.324 horas.
#
# --- Fim do dia 7 ---
# Esportes executados: Natação, Pentatlo Moderno, Polo Aquático, Remo, Rugby Sevens, Saltos Ornamentais
#
# Total de horas de esportes executados no dia 7: 13.657 horas
# --- Início do dia 8 ---
#
# Modalidade Tênis concluída após 1.037 horas.
# Modalidade Tênis de Mesa concluída após 1.124 horas.
# Modalidade Skate concluída após 1.526 horas.
# Modalidade Surfe concluída após 2.463 horas.
# Modalidade Taekwondo concluída após 4.952 horas.
#
# --- Fim do dia 8 ---
# Esportes executados: Skate, Surfe, Taekwondo, Tênis, Tênis de Mesa
#
# Total de horas de esportes executados no dia 8: 11.101 horas
# --- Início do dia 9 ---
#
# Modalidade Vela concluída após 0.065 horas.
# Modalidade Triatlo concluída após 0.092 horas.
# Modalidade Vôlei de Praia concluída após 0.221 horas.
# Modalidade Vôlei concluída após 0.322 horas.
# Modalidade Tiro Esportivo concluída após 2.100 horas.
# Modalidade Tiro com Arco concluída após 4.813 horas.
#
# --- Fim do dia 9 ---
# Esportes executados: Tiro com Arco, Tiro Esportivo, Triatlo, Vela, Vôlei, Vôlei de Praia
#
# Total de horas de esportes executados no dia 9: 7.613 horas
# Os Jogos Olímpicos em Paris 2024 foram finalizados após 9 dias!

# %% [markdown]
# ### **Código - sem time.sleep e com day_duration**

# %% [markdown]
# - primeiro cria as Threads e armazena em executed_thread
# - depois executa todas juntas

# %%
import threading
import time
import random
from sports import sports


# Função para simular a execução do esporte, com título e duração específica
def sport(title, duration, results, lock):
    start_time = time.perf_counter()  # Captura o tempo inicial
    print(f'Modalidade {title} - TEMPO INICIO: {start_time:.3f}')
    
    # Simula o tempo de execução (em horas convertidas para segundos)
    elapsed_time = 0
    time_count = 0.1

    while elapsed_time < duration:
        elapsed_time += time_count

    end_time = time.perf_counter()  # Captura o tempo final
    elapsed_time = end_time - start_time

    print(f'Modalidade {title} - TEMPO FINAL: {end_time:.3f}, Espera: {elapsed_time:.3f} horas')

    # Registra a execução do esporte e a duração total com lock para evitar concorrência
    with lock:
        results.append((title, duration, elapsed_time))


# Função para simular o início dos Jogos Olímpicos
def start_olympics():
    print('\nOs Jogos Olímpicos em Paris 2024 foram iniciados!\n')
    
    day_duration = 12  # Limite de horas por dia
    day_count = 0  # Contador de dias
    all_sports = sports.copy()  # Copia todas as modalidades
    pending_sports = []  # Lista de esportes pendentes para o próximo dia

    lock = threading.Lock()

    while all_sports or pending_sports:
        day_count += 1
        print(f'--- Início do dia {day_count} ---\n')

        day_remaining = day_duration  
        executed_threads = []
        results = []  
        executed_sports = []  
        daily_total_hours = 0  

        # Adiciona esportes pendentes para execução do dia
        for title, duration in pending_sports:
            if duration <= day_remaining:  
                t = threading.Thread(target=sport, args=(title, duration, results, lock))
                executed_threads.append(t)
                day_remaining -= duration
            else:
                break  
        pending_sports = pending_sports[len(executed_threads):]  # Remove os esportes que foram executados

        # Adiciona novos esportes para o dia
        while all_sports and day_remaining > 0:
            title = random.choice(all_sports)
            all_sports.remove(title)
            duration = random.uniform((1/60), 5)  

            # Verifica se o esporte cabe no tempo restante do dia
            if duration <= day_remaining:
                t = threading.Thread(target=sport, args=(title, duration, results, lock))
                executed_threads.append(t)
                day_remaining -= duration
            else:
                pending_sports.append((title, duration))

        # Inicia todas as threads de esportes juntas
        for t in executed_threads:
            t.start()

        # Aguarda a finalização de todas as threads
        for t in executed_threads:
            t.join()

        # Processa os resultados e soma as horas do dia
        for title, duration, elapsed_time in results:
            executed_sports.append(title)
            daily_total_hours += duration

        print(f'\n--- Fim do dia {day_count} ---\nEsportes executados: {executed_sports}\n')
        print(f'Total de horas de esportes executados no dia {day_count}: {daily_total_hours:.3f} horas\n')

    print(f'Os Jogos Olímpicos em Paris 2024 foram finalizados após {day_count} dias!\n')


# Inicia a simulação dos Jogos Olímpicos
start_olympics()
# Out:
# Os Jogos Olímpicos em Paris 2024 foram iniciados!
#
# --- Início do dia 1 ---
#
# Modalidade Levantamento de Peso - TEMPO INICIO: 1953893.749
# Modalidade Levantamento de Peso - TEMPO FINAL: 1953893.749, Espera: 0.000 horas
# Modalidade Judô - TEMPO INICIO: 1953893.750
# Modalidade Judô - TEMPO FINAL: 1953893.750, Espera: 0.000 horas
# Modalidade Ciclismo de Estrada - TEMPO INICIO: 1953893.750
# Modalidade Ciclismo de Estrada - TEMPO FINAL: 1953893.750, Espera: 0.000 horas
# Modalidade Polo Aquático - TEMPO INICIO: 1953893.751
# Modalidade Polo Aquático - TEMPO FINAL: 1953893.751, Espera: 0.000 horas
# Modalidade Ciclismo Bmx Racing - TEMPO INICIO: 1953893.751
# Modalidade Ciclismo Bmx Racing - TEMPO FINAL: 1953893.751, Espera: 0.000 horas
# Modalidade Surfe - TEMPO INICIO: 1953893.751
# Modalidade Surfe - TEMPO FINAL: 1953893.751, Espera: 0.000 horas
# Modalidade Basquete 3x3 - TEMPO INICIO: 1953893.751
# Modalidade Basquete 3x3 - TEMPO FINAL: 1953893.751, Espera: 0.000 horas
#
# --- Fim do dia 1 ---
# Esportes executados: ['Levantamento de Peso', 'Judô', 'Ciclismo de Estrada', 'Polo Aquático', 'Ciclismo Bmx Racing', 'Surfe', 'Basquete 3x3']
#
# Total de horas de esportes executados no dia 1: 11.982 horas
#
# --- Início do dia 2 ---
#
# Modalidade Vela - TEMPO INICIO: 1953893.752
# Modalidade Vela - TEMPO FINAL: 1953893.752, Espera: 0.000 horas
# Modalidade Remo - TEMPO INICIO: 1953893.752
# Modalidade Remo - TEMPO FINAL: 1953893.752, Espera: 0.000 horas
# Modalidade Maratona Aquática - TEMPO INICIO: 1953893.752
# Modalidade Maratona Aquática - TEMPO FINAL: 1953893.752, Espera: 0.000 horas
# Modalidade Hipismo - TEMPO INICIO: 1953893.752
# Modalidade Hipismo - TEMPO FINAL: 1953893.752, Espera: 0.000 horas
# Modalidade Ginástica Rítmica - TEMPO INICIO: 1953893.752
# Modalidade Ginástica Rítmica - TEMPO FINAL: 1953893.752, Espera: 0.000 horas
# Modalidade Badminton - TEMPO INICIO: 1953893.752
# Modalidade Badminton - TEMPO FINAL: 1953893.752, Espera: 0.000 horas
#
# --- Fim do dia 2 ---
# Esportes executados: ['Vela', 'Remo', 'Maratona Aquática', 'Hipismo', 'Ginástica Rítmica', 'Badminton']
#
# Total de horas de esportes executados no dia 2: 11.999 horas
#
# --- Início do dia 3 ---
#
# Modalidade Vôlei de Praia - TEMPO INICIO: 1953893.753
# Modalidade Vôlei de Praia - TEMPO FINAL: 1953893.753, Espera: 0.000 horas
# Modalidade Tênis - TEMPO INICIO: 1953893.753
# Modalidade Tênis - TEMPO FINAL: 1953893.753, Espera: 0.000 horas
# Modalidade Tiro com Arco - TEMPO INICIO: 1953893.753
# Modalidade Tiro com Arco - TEMPO FINAL: 1953893.753, Espera: 0.000 horas
# Modalidade Ciclismo Mountain Bike - TEMPO INICIO: 1953893.753
# Modalidade Ciclismo Mountain Bike - TEMPO FINAL: 1953893.753, Espera: 0.000 horas
# Modalidade Breaking - TEMPO INICIO: 1953893.753
# Modalidade Breaking - TEMPO FINAL: 1953893.753, Espera: 0.000 horas
#
# --- Fim do dia 3 ---
# Esportes executados: ['Vôlei de Praia', 'Tênis', 'Tiro com Arco', 'Ciclismo Mountain Bike', 'Breaking']
#
# Total de horas de esportes executados no dia 3: 7.250 horas
#
# --- Início do dia 4 ---
#
# Modalidade Atletismo - TEMPO INICIO: 1953893.753
# Modalidade Atletismo - TEMPO FINAL: 1953893.753, Espera: 0.000 horas
# Modalidade Ciclismo de Pista - TEMPO INICIO: 1953893.753
# Modalidade Ciclismo de Pista - TEMPO FINAL: 1953893.753, Espera: 0.000 horas
# Modalidade Esgrima - TEMPO INICIO: 1953893.754
# Modalidade Esgrima - TEMPO FINAL: 1953893.754, Espera: 0.000 horas
# Modalidade Escalada - TEMPO INICIO: 1953893.754
# Modalidade Escalada - TEMPO FINAL: 1953893.754, Espera: 0.000 horas
# Modalidade Ginástica Artística - TEMPO INICIO: 1953893.754
# Modalidade Ginástica Artística - TEMPO FINAL: 1953893.754, Espera: 0.000 horas
# Modalidade Pentatlo Moderno - TEMPO INICIO: 1953893.754
# Modalidade Pentatlo Moderno - TEMPO FINAL: 1953893.754, Espera: 0.000 horas
#
# --- Fim do dia 4 ---
# Esportes executados: ['Atletismo', 'Ciclismo de Pista', 'Esgrima', 'Escalada', 'Ginástica Artística', 'Pentatlo Moderno']
#
# Total de horas de esportes executados no dia 4: 10.203 horas
#
# --- Início do dia 5 ---
#
# Modalidade Nado Artístico - TEMPO INICIO: 1953893.754
# Modalidade Nado Artístico - TEMPO FINAL: 1953893.754, Espera: 0.000 horas
# Modalidade Canoagem de Velocidade - TEMPO INICIO: 1953893.754
# Modalidade Canoagem de Velocidade - TEMPO FINAL: 1953893.754, Espera: 0.000 horas
# Modalidade Vôlei - TEMPO INICIO: 1953893.755
# Modalidade Vôlei - TEMPO FINAL: 1953893.755, Espera: 0.000 horas
# Modalidade Tiro Esportivo - TEMPO INICIO: 1953893.755
# Modalidade Tiro Esportivo - TEMPO FINAL: 1953893.755, Espera: 0.000 horas
# Modalidade Handebol - TEMPO INICIO: 1953893.755
# Modalidade Handebol - TEMPO FINAL: 1953893.755, Espera: 0.000 horas
#
# --- Fim do dia 5 ---
# Esportes executados: ['Nado Artístico', 'Canoagem de Velocidade', 'Vôlei', 'Tiro Esportivo', 'Handebol']
#
# Total de horas de esportes executados no dia 5: 9.564 horas
#
# --- Início do dia 6 ---
#
# Modalidade Boxe - TEMPO INICIO: 1953893.755
# Modalidade Boxe - TEMPO FINAL: 1953893.755, Espera: 0.000 horas
# Modalidade Hóquei sobre Grama - TEMPO INICIO: 1953893.755
# Modalidade Hóquei sobre Grama - TEMPO FINAL: 1953893.755, Espera: 0.000 horas
# Modalidade Basquete - TEMPO INICIO: 1953893.755
# Modalidade Basquete - TEMPO FINAL: 1953893.755, Espera: 0.000 horas
# Modalidade Skate - TEMPO INICIO: 1953893.755
# Modalidade Skate - TEMPO FINAL: 1953893.755, Espera: 0.000 horas
#
# --- Fim do dia 6 ---
# Esportes executados: ['Boxe', 'Hóquei sobre Grama', 'Basquete', 'Skate']
#
# Total de horas de esportes executados no dia 6: 11.968 horas
#
# --- Início do dia 7 ---
#
# Modalidade Triatlo - TEMPO INICIO: 1953893.755
# Modalidade Triatlo - TEMPO FINAL: 1953893.755, Espera: 0.000 horas
# Modalidade Ginástica de Trampolim - TEMPO INICIO: 1953893.756
# Modalidade Ginástica de Trampolim - TEMPO FINAL: 1953893.756, Espera: 0.000 horas
# Modalidade Taekwondo - TEMPO INICIO: 1953893.756
# Modalidade Taekwondo - TEMPO FINAL: 1953893.756, Espera: 0.000 horas
# Modalidade Saltos Ornamentais - TEMPO INICIO: 1953893.756
# Modalidade Saltos Ornamentais - TEMPO FINAL: 1953893.756, Espera: 0.000 horas
# Modalidade Natação - TEMPO INICIO: 1953893.756
# Modalidade Natação - TEMPO FINAL: 1953893.756, Espera: 0.000 horas
#
# --- Fim do dia 7 ---
# Esportes executados: ['Triatlo', 'Ginástica de Trampolim', 'Taekwondo', 'Saltos Ornamentais', 'Natação']
#
# Total de horas de esportes executados no dia 7: 10.173 horas
#
# --- Início do dia 8 ---
#
# Modalidade Luta - TEMPO INICIO: 1953893.756
# Modalidade Luta - TEMPO FINAL: 1953893.756, Espera: 0.000 horas
# Modalidade Futebol - TEMPO INICIO: 1953893.756
# Modalidade Futebol - TEMPO FINAL: 1953893.756, Espera: 0.000 horas
# Modalidade Canoagem Slalom - TEMPO INICIO: 1953893.756
# Modalidade Canoagem Slalom - TEMPO FINAL: 1953893.756, Espera: 0.000 horas
# Modalidade Rugby Sevens - TEMPO INICIO: 1953893.756
# Modalidade Rugby Sevens - TEMPO FINAL: 1953893.756, Espera: 0.000 horas
# Modalidade Ciclismo Bmx Freestyle - TEMPO INICIO: 1953893.757
# Modalidade Ciclismo Bmx Freestyle - TEMPO FINAL: 1953893.757, Espera: 0.000 horas
#
# --- Fim do dia 8 ---
# Esportes executados: ['Luta', 'Futebol', 'Canoagem Slalom', 'Rugby Sevens', 'Ciclismo Bmx Freestyle']
#
# Total de horas de esportes executados no dia 8: 9.367 horas
#
# --- Início do dia 9 ---
#
# Modalidade Golfe - TEMPO INICIO: 1953893.757
# Modalidade Golfe - TEMPO FINAL: 1953893.757, Espera: 0.000 horas
# Modalidade Tênis de Mesa - TEMPO INICIO: 1953893.757
# Modalidade Tênis de Mesa - TEMPO FINAL: 1953893.757, Espera: 0.000 horas
#
# --- Fim do dia 9 ---
# Esportes executados: ['Golfe', 'Tênis de Mesa']
#
# Total de horas de esportes executados no dia 9: 5.012 horas
#
# Os Jogos Olímpicos em Paris 2024 foram finalizados após 9 dias!

# %% [markdown]
# ### **Agradecemos a atenção!** 😊
